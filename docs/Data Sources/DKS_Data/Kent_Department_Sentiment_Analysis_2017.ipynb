# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk 
from nltk.tokenize import word_tokenize
import emoji
from emoji.unicode_codes import UNICODE_EMOJI

# %%
#loading the data into the dataframe after removing some columns manually from CSV file
data=pd.read_csv('D:\\Manisha\\Undergrad_Semester\\Semesters\\Fall2019\\capstone\\\data_sources\\Destination_Kent_State_Student_Evaluation_2017.csv', encoding = 'unicode_escape')

# %%
data.head()
# Out:
#   OnlinePlacementAssessment     AcademicAdvising  \
# 0       Open-Ended Response  Open-Ended Response
# 1                       NaN                  NaN
# 2                       NaN                  NaN
# 3                       NaN                  NaN
# 4                       NaN                  NaN
#
#   CollegeOpportunitiesandAdvisingPrep spendMoreTimeDestinationKentState  \
# 0                 Open-Ended Response               Open-Ended Response
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                      Campus tours
# 4                                 NaN                               NaN
#
#                   favoritePartDestinationKentState  \
# 0                              Open-Ended Response
# 1                                              NaN
# 2                                              NaN
# 3                                            Lunch
# 4  Spending a night in the dorms was very helpful.
#
#                          expectedAsAKentStateStudent anyAdditionalComments
# 0                                Open-Ended Response   Open-Ended Response
# 1      To graduate with a diploma and give you money                   NaN
# 2                                                NaN                   NaN
# 3                                     To do my best.                   NaN
# 4  To be involved in campus activities and mainta...                   NaN

# %%
#a.encode('utf-8').strip()

# %%
colname=data.columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1295 entries, 0 to 1294
# Data columns (total 7 columns):
# OnlinePlacementAssessment              282 non-null object
# AcademicAdvising                       299 non-null object
# CollegeOpportunitiesandAdvisingPrep    125 non-null object
# spendMoreTimeDestinationKentState      442 non-null object
# favoritePartDestinationKentState       707 non-null object
# expectedAsAKentStateStudent            1023 non-null object
# anyAdditionalComments                  159 non-null object
# dtypes: object(7)
# memory usage: 70.9+ KB

# %%
len(data.columns)
# Out:
# 7

# %%
#data cleaning steps
for x in data.columns:
    for i in range(len(data)):
        # Remove the word starting with @
        data.loc[i,x] = re.sub(r'@[A-Za-z0-9]+', ' ', str(data.loc[i,x]))
  
        #Remove URL links
        data.loc[i,x]  = re.sub('https?://[A-Za-z0-9./]+',' ',data.loc[i,x] ) 
        data.loc[i,x]  = re.sub('http?://[A-Za-z0-9./]+',' ',data.loc[i,x] )

        # Converting to Lowercase
        data.loc[i,x]  = data.loc[i,x] .lower()
        
        #Remove the new line characters
        data.loc[i,x] = re.sub(r"\t|\n|\r", " ", data.loc[i,x] , flags=re.I)
    
        #Remove punctuation
        data.loc[i,x] = re.sub(r"[,@\#:'?\.$%_!()]", " ", data.loc[i,x] , flags=re.I)

        #Remove digits
        data.loc[i,x] = re.sub(r"\d", "", data.loc[i,x] )

        # remove all single characters
        data.loc[i,x] = re.sub(r'\s+[a-zA-Z]\s+', ' ', data.loc[i,x] )

        # Substituting multiple spaces with single space
        data.loc[i,x]  = re.sub(r'\s+', ' ', data.loc[i,x] , flags=re.I)

# %%
data
# Out:
#                               OnlinePlacementAssessment  \
# 0                                   open-ended response
# 1                                                   nan
# 2                                                   nan
# 3                                                   nan
# 4                                                   nan
# 5                                                   nan
# 6                                                   nan
# 7                                                   nan
# 8                                                   nan
# 9                                                   nan
# 10                                                  nan
# 11    make sure that they set good amount of time as...
# 12                                                  nan
# 13                                                  nan
# 14                                                  nan
# 15                                                  nan
# 16                                                  nan
# 17    level out the difficulty of the test to maybe ...
# 18                                                  nan
# 19                                                  nan
# 20    multiple choice because answers could be right...
# 21                                                  nan
# 22                                                  nan
# 23                                                  nan
# 24    no only had to take one placement test because...
# 25                                                 none
# 26                                                  nan
# 27                                                  nan
# 28                                                   no
# 29                                                  nan
# ...                                                 ...
# 1265                                                nan
# 1266                                                nan
# 1267                                                nan
# 1268                                                nan
# 1269  feedback was not clear on how many times could...
# 1270                                                nan
# 1271                                                nan
# 1272  both the math and foreign language assessments...
# 1273                                                nan
# 1274                                                nan
# 1275                                                nan
# 1276                                                nan
# 1277                                                nan
# 1278                                                nan
# 1279  i had to receive different link to take the sp...
# 1280                                                nan
# 1281                                                nan
# 1282  update it and/or use more modern system of tes...
# 1283                                                nan
# 1284                                                nan
# 1285                                                nan
# 1286  the foreign language placement test had some i...
# 1287                                                nan
# 1288                                                nan
# 1289                                                nan
# 1290                                                nan
# 1291                                                nan
# 1292                                                nan
# 1293                                                nan
# 1294                                                nan
#
#                                        AcademicAdvising  \
# 0                                   open-ended response
# 1                                                   nan
# 2                                                   nan
# 3                                                   nan
# 4                                                   nan
# 5                                                   nan
# 6                                                   nan
# 7                                                   nan
# 8                                                   nan
# 9                                                   nan
# 10                                                  nan
# 11    allow more time for students to plan their sch...
# 12                                                  nan
# 13                                                  nan
# 14                                                  nan
# 15                                                  nan
# 16                                                  nan
# 17    this was incredibly helpful took some time sch...
# 18                                                  nan
# 19    i had an appointment at and she didn meet with...
# 20    better backup plan when gas leak happened lead...
# 21                                                  nan
# 22                                                  nan
# 23                                                  nan
# 24    my advisor was amazing and we actually went ov...
# 25                                                  nan
# 26    they did not seem very eager to figuring out h...
# 27                                                  nan
# 28                                                  nan
# 29                                                  nan
# ...                                                 ...
# 1265                                                nan
# 1266                                                nan
# 1267                                                nan
# 1268  besides the waiting for an hour it was good ex...
# 1269                                                nan
# 1270                                                nan
# 1271                                                nan
# 1272                                                nan
# 1273                                                nan
# 1274                                                nan
# 1275                                                nan
# 1276  i didn get to meet with my advisor instead met...
# 1277                                                nan
# 1278                                                nan
# 1279  on the first day learning about the classes wo...
# 1280                                                nan
# 1281                                                nan
# 1282                                                nan
# 1283                                                nan
# 1284                                                nan
# 1285                                                nan
# 1286                                                nan
# 1287                                                nan
# 1288  my advisor was very friendly and open to any q...
# 1289                          i thought it was amazing
# 1290                                                nan
# 1291  my advisor maria was really nice and helpful m...
# 1292                                                nan
# 1293                                                nan
# 1294                                                nan
#
#                     CollegeOpportunitiesandAdvisingPrep  \
# 0                                   open-ended response
# 1                                                   nan
# 2                                                   nan
# 3                                                   nan
# 4                                                   nan
# 5                                                   nan
# 6                                                   nan
# 7                                                   nan
# 8                                                   nan
# 9                                                   nan
# 10                                                  nan
# 11                                                  nan
# 12                                                  nan
# 13                                                  nan
# 14                                                  nan
# 15                                                  nan
# 16                                                  nan
# 17    it was beautiful experience full of genuinely ...
# 18                                                  nan
# 19                                                  nan
# 20                                                  nan
# 21                                                  nan
# 22                                                  nan
# 23                                                  nan
# 24                                                  nan
# 25                                                  nan
# 26                                                  nan
# 27                                                  nan
# 28                                                  nan
# 29                                                  nan
# ...                                                 ...
# 1265                                                nan
# 1266                                                nan
# 1267                                                nan
# 1268                                                nan
# 1269                                                nan
# 1270                                                nan
# 1271                                                nan
# 1272                                                nan
# 1273                                                nan
# 1274                                                nan
# 1275                                                nan
# 1276                                                nan
# 1277                                                nan
# 1278                                                nan
# 1279  more time needs to be spent on talking about a...
# 1280                                                nan
# 1281                                                nan
# 1282                                                nan
# 1283                                                nan
# 1284                                                nan
# 1285                                                nan
# 1286                                                nan
# 1287                                                nan
# 1288                                                nan
# 1289                                       it was good
# 1290                                                nan
# 1291                                                nan
# 1292                                                nan
# 1293                                                nan
# 1294                                                nan
#
#                       spendMoreTimeDestinationKentState  \
# 0                                   open-ended response
# 1                                                   nan
# 2                                                   nan
# 3                                          campus tours
# 4                                                   nan
# 5                                                   nan
# 6                                                   nan
# 7                                                   no
# 8            how college is different from high school
# 9                                                   nan
# 10                                                  nan
# 11    make sure that students get to walk to there c...
# 12                    buying books and when to do that
# 13                         timeline of billing process
# 14                                                  nan
# 15                                                  nan
# 16                                                  nan
# 17         tours please also snacks would be great too
# 18                                                  nan
# 19    student athletes that live on campus during th...
# 20                                                  nan
# 21                                                  nan
# 22         tours of campus and downtown give more time
# 23                                                  nan
# 24                                                   no
# 25                                                  nan
# 26                                                  nan
# 27                                                  nan
# 28                                                   no
# 29                                                  nan
# ...                                                 ...
# 1265                                                nan
# 1266                                                nan
# 1267                                                nan
# 1268                                                nan
# 1269                                                nan
# 1270  definetly on touring the campus but more along...
# 1271                                            parking
# 1272                                                nan
# 1273                                                nan
# 1274                                                nan
# 1275                      broader tour of entire campus
# 1276                                                nan
# 1277                                                nan
# 1278                                                nan
# 1279  dks should be time to schedule classes and mee...
# 1280                                                nan
# 1281                                        ccp credits
# 1282                                                nan
# 1283                                                nan
# 1284                                                nan
# 1285                                                nan
# 1286                                                nan
# 1287                                                nan
# 1288                                                nan
# 1289                            an in depth campus tour
# 1290                                                nan
# 1291                                                nan
# 1292                                                nan
# 1293                                                nan
# 1294                      more time learning the campus
#
#                        favoritePartDestinationKentState  \
# 0                                   open-ended response
# 1                                                   nan
# 2                                                   nan
# 3                                                 lunch
# 4         spending night in the dorms was very helpful
# 5                                                   nan
# 6                                                   nan
# 7     it would be touring downtown kent walking arou...
# 8     talking to the flash guides about their experi...
# 9     talking to the flashguides about how life is l...
# 10                                                  nan
# 11    my favorite part was hearing teh flashguide st...
# 12                                                food
# 13    downtown tour great way to get feel of surroun...
# 14                                                  nan
# 15                                                  nan
# 16                                                  nan
# 17    i really enjoyed the downtime you guys include...
# 18    going into town and being able to walk around ...
# 19                                                  nan
# 20                                             the fair
# 21                                                  nan
# 22                            the first lecture section
# 23                       i liked the night time social
# 24        touring downtown kent and making new friends
# 25                               going to downtown kent
# 26                                                  nan
# 27                                  meeting my roommate
# 28    when we went to our specific area of major and...
# 29                                                  nan
# ...                                                 ...
# 1265                                                nan
# 1266                                                nan
# 1267                                                nan
# 1268                                                nan
# 1269                                                nan
# 1270  i absolutely loved the flashguides and am conf...
# 1271     being able to spend sometime with my roommate
# 1272                                                nan
# 1273                             the evening activities
# 1274                                          the food
# 1275  meeting my roomie for the experience and makin...
# 1276                                                nan
# 1277                                                nan
# 1278                                                nan
# 1279  my favorite part was the end of day when the f...
# 1280                                                nan
# 1281  walking around downtown and meeting new people...
# 1282                                                nan
# 1283  i liked spending time with other students from...
# 1284                                                nan
# 1285                                                nan
# 1286                                                nan
# 1287                                                nan
# 1288                                                nan
# 1289  the academic advising was my favorite part bec...
# 1290                                                nan
# 1291  my favorite part about the program was that it...
# 1292                                                nan
# 1293                                                nan
# 1294  the free time the presentations were so long a...
#
#                             expectedAsAKentStateStudent  \
# 0                                   open-ended response
# 1           to graduate with diploma and give you money
# 2                                                   nan
# 3                                        to do my best
# 4     to be involved in campus activities and mainta...
# 5                                                   nan
# 6                                                   nan
# 7     to carry myself e actions words decisions in w...
# 8        doing my work on time without procrastinating
# 9     do well and show the community can behave and ...
# 10                                                  nan
# 11    i believe that am expected to follow the rules...
# 12             to live up to my goals and expectations
# 13                                             succeed
# 14                     to pass my classes and not fail
# 15       be self sufficient independent and responsible
# 16                                                  nan
# 17                  ** success and genuine happiness **
# 18                            get involved and succeed
# 19                                             do well
# 20                                           being nice
# 21                                                  nan
# 22    to grow in yourself personally and academicall...
# 23    to do the best you can and get help by the man...
# 24    to get involved as much as possible make frien...
# 25    to strive for excellence in and out of the cla...
# 26                            hard work and commitment
# 27                                to get needed credits
# 28                                      to be involved
# 29    to hold up my best academic hand so myself can...
# ...                                                 ...
# 1265                                                nan
# 1266  to be successful and take studying seriously w...
# 1267                                                nan
# 1268                                                nan
# 1269                     quality work completed on time
# 1270  to not only have an educational experience but...
# 1271  to maintain and achieve high goals in academic...
# 1272                                                nan
# 1273                                         to succeed
# 1274        to make the most of my years at kent state
# 1275  to get involved study hard but enjoy my colleg...
# 1276                           be ethical work hard etc
# 1277                                                nan
# 1278             to get good grades and to study abroad
# 1279  to get involved make friends and keep up with ...
# 1280                      involvement at the university
# 1281  take your education seriously but also have fu...
# 1282  get involved go to class/get my degree & find ...
# 1283  i believe that should be an academically succe...
# 1284                                            do good
# 1285                                     being an adult
# 1286                                                nan
# 1287                      set goals and stick with them
# 1288                                                nan
# 1289               academic excellence and self purpose
# 1290                                                nan
# 1291  i expected to do my best to become successful ...
# 1292                                        behave well
# 1293                                        excellence
# 1294                                        to graduate
#
#                                   anyAdditionalComments
# 0                                   open-ended response
# 1                                                   nan
# 2                                                   nan
# 3                                                   nan
# 4                                                   nan
# 5                                                   nan
# 6                                                   nan
# 7                                                   nan
# 8                                                   nan
# 9                                                   nan
# 10                                                  nan
# 11                                                  nan
# 12                                                  nan
# 13                                                  nan
# 14                                                  nan
# 15                                                  nan
# 16                                                  nan
# 17    i appreciate each & every one of you supporter...
# 18                                                  nan
# 19                                                  nan
# 20                                                  nan
# 21                                                  nan
# 22                                                  nan
# 23                                                  nan
# 24                                                  nan
# 25                                                  nan
# 26                                                  nan
# 27                                                  nan
# 28            loved this opportunity would do it again
# 29                                                  nan
# ...                                                 ...
# 1265                                                nan
# 1266                                                nan
# 1267                                                nan
# 1268                                                nan
# 1269                                                nan
# 1270                                        go flashes
# 1271                                                nan
# 1272                                                nan
# 1273  use different teacher to teach us "our first c...
# 1274                                                nan
# 1275                                                nan
# 1276                                                nan
# 1277                                                nan
# 1278                                                nan
# 1279  i suggest that on day mix up the schedule and ...
# 1280                                                nan
# 1281                                                nan
# 1282                                                nan
# 1283                                                nan
# 1284                                                nan
# 1285                                                nan
# 1286                                                nan
# 1287                                                nan
# 1288                                                nan
# 1289  i would have liked to have the flash guides be...
# 1290                                                nan
# 1291                                                nan
# 1292                                                nan
# 1293                                                nan
# 1294                                                nan
#
# [1295 rows x 7 columns]

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gautam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
## split into words, create tokens
from nltk.tokenize import word_tokenize
for x in data.columns:
    for i in range(len(data)):
        data.loc[i,x] = word_tokenize(str(data.loc[i,x]))

# %%
data.head(15)
# Out:
#                             OnlinePlacementAssessment  \
# 0                              [open-ended, response]
# 1                                               [nan]
# 2                                               [nan]
# 3                                               [nan]
# 4                                               [nan]
# 5                                               [nan]
# 6                                               [nan]
# 7                                               [nan]
# 8                                               [nan]
# 9                                               [nan]
# 10                                              [nan]
# 11  [make, sure, that, they, set, good, amount, of...
# 12                                              [nan]
# 13                                              [nan]
# 14                                              [nan]
#
#                                      AcademicAdvising  \
# 0                              [open-ended, response]
# 1                                               [nan]
# 2                                               [nan]
# 3                                               [nan]
# 4                                               [nan]
# 5                                               [nan]
# 6                                               [nan]
# 7                                               [nan]
# 8                                               [nan]
# 9                                               [nan]
# 10                                              [nan]
# 11  [allow, more, time, for, students, to, plan, t...
# 12                                              [nan]
# 13                                              [nan]
# 14                                              [nan]
#
#    CollegeOpportunitiesandAdvisingPrep  \
# 0               [open-ended, response]
# 1                                [nan]
# 2                                [nan]
# 3                                [nan]
# 4                                [nan]
# 5                                [nan]
# 6                                [nan]
# 7                                [nan]
# 8                                [nan]
# 9                                [nan]
# 10                               [nan]
# 11                               [nan]
# 12                               [nan]
# 13                               [nan]
# 14                               [nan]
#
#                     spendMoreTimeDestinationKentState  \
# 0                              [open-ended, response]
# 1                                               [nan]
# 2                                               [nan]
# 3                                     [campus, tours]
# 4                                               [nan]
# 5                                               [nan]
# 6                                               [nan]
# 7                                                [no]
# 8   [how, college, is, different, from, high, school]
# 9                                               [nan]
# 10                                              [nan]
# 11  [make, sure, that, students, get, to, walk, to...
# 12           [buying, books, and, when, to, do, that]
# 13                   [timeline, of, billing, process]
# 14                                              [nan]
#
#                      favoritePartDestinationKentState  \
# 0                              [open-ended, response]
# 1                                               [nan]
# 2                                               [nan]
# 3                                             [lunch]
# 4   [spending, night, in, the, dorms, was, very, h...
# 5                                               [nan]
# 6                                               [nan]
# 7   [it, would, be, touring, downtown, kent, walki...
# 8   [talking, to, the, flash, guides, about, their...
# 9   [talking, to, the, flashguides, about, how, li...
# 10                                              [nan]
# 11  [my, favorite, part, was, hearing, teh, flashg...
# 12                                             [food]
# 13  [downtown, tour, great, way, to, get, feel, of...
# 14                                              [nan]
#
#                           expectedAsAKentStateStudent   anyAdditionalComments
# 0                              [open-ended, response]  [open-ended, response]
# 1   [to, graduate, with, diploma, and, give, you, ...                   [nan]
# 2                                               [nan]                   [nan]
# 3                                  [to, do, my, best]                   [nan]
# 4   [to, be, involved, in, campus, activities, and...                   [nan]
# 5                                               [nan]                   [nan]
# 6                                               [nan]                   [nan]
# 7   [to, carry, myself, e, actions, words, decisio...                   [nan]
# 8   [doing, my, work, on, time, without, procrasti...                   [nan]
# 9   [do, well, and, show, the, community, can, beh...                   [nan]
# 10                                              [nan]                   [nan]
# 11  [i, believe, that, am, expected, to, follow, t...                   [nan]
# 12   [to, live, up, to, my, goals, and, expectations]                   [nan]
# 13                                          [succeed]                   [nan]
# 14            [to, pass, my, classes, and, not, fail]                   [nan]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gautam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
for x in data.columns:
    for i in range(len(data)):
        data.loc[i,x] = [word for word in data.loc[i,x] if not word in stop_words]

# %%
data.head(15)
# Out:
#                             OnlinePlacementAssessment  \
# 0                              [open-ended, response]
# 1                                               [nan]
# 2                                               [nan]
# 3                                               [nan]
# 4                                               [nan]
# 5                                               [nan]
# 6                                               [nan]
# 7                                               [nan]
# 8                                               [nan]
# 9                                               [nan]
# 10                                              [nan]
# 11  [make, sure, set, good, amount, time, aside, e...
# 12                                              [nan]
# 13                                              [nan]
# 14                                              [nan]
#
#                                     AcademicAdvising  \
# 0                             [open-ended, response]
# 1                                              [nan]
# 2                                              [nan]
# 3                                              [nan]
# 4                                              [nan]
# 5                                              [nan]
# 6                                              [nan]
# 7                                              [nan]
# 8                                              [nan]
# 9                                              [nan]
# 10                                             [nan]
# 11  [allow, time, students, plan, schedule, meeting]
# 12                                             [nan]
# 13                                             [nan]
# 14                                             [nan]
#
#    CollegeOpportunitiesandAdvisingPrep  \
# 0               [open-ended, response]
# 1                                [nan]
# 2                                [nan]
# 3                                [nan]
# 4                                [nan]
# 5                                [nan]
# 6                                [nan]
# 7                                [nan]
# 8                                [nan]
# 9                                [nan]
# 10                               [nan]
# 11                               [nan]
# 12                               [nan]
# 13                               [nan]
# 14                               [nan]
#
#                     spendMoreTimeDestinationKentState  \
# 0                              [open-ended, response]
# 1                                               [nan]
# 2                                               [nan]
# 3                                     [campus, tours]
# 4                                               [nan]
# 5                                               [nan]
# 6                                               [nan]
# 7                                                  []
# 8                  [college, different, high, school]
# 9                                               [nan]
# 10                                              [nan]
# 11  [make, sure, students, get, walk, classes, kno...
# 12                                    [buying, books]
# 13                       [timeline, billing, process]
# 14                                              [nan]
#
#                      favoritePartDestinationKentState  \
# 0                              [open-ended, response]
# 1                                               [nan]
# 2                                               [nan]
# 3                                             [lunch]
# 4                   [spending, night, dorms, helpful]
# 5                                               [nan]
# 6                                               [nan]
# 7   [would, touring, downtown, kent, walking, arou...
# 8               [talking, flash, guides, experiences]
# 9   [talking, flashguides, life, like, campus, per...
# 10                                              [nan]
# 11  [favorite, part, hearing, teh, flashguide, sto...
# 12                                             [food]
# 13  [downtown, tour, great, way, get, feel, surrou...
# 14                                              [nan]
#
#                           expectedAsAKentStateStudent   anyAdditionalComments
# 0                              [open-ended, response]  [open-ended, response]
# 1                    [graduate, diploma, give, money]                   [nan]
# 2                                               [nan]                   [nan]
# 3                                              [best]                   [nan]
# 4   [involved, campus, activities, maintain, solid...                   [nan]
# 5                                               [nan]                   [nan]
# 6                                               [nan]                   [nan]
# 7   [carry, e, actions, words, decisions, way, rep...                   [nan]
# 8              [work, time, without, procrastinating]                   [nan]
# 9       [well, show, community, behave, great, human]                   [nan]
# 10                                              [nan]                   [nan]
# 11  [believe, expected, follow, rules, try, best, ...                   [nan]
# 12                        [live, goals, expectations]                   [nan]
# 13                                          [succeed]                   [nan]
# 14                              [pass, classes, fail]                   [nan]

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gautam\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Lemmetization of words (it will change the word in the base form)
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
for x in data.columns:
    for i in range(len(data)):
        data.loc[i,x] = [lemmatizer.lemmatize(word,pos='a') for word in data.loc[i,x]]
        data.loc[i,x] = [lemmatizer.lemmatize(word,pos='v') for word in data.loc[i,x]]
        data.loc[i,x] = [lemmatizer.lemmatize(word,pos='n') for word in data.loc[i,x]]

# %%
data.head(15)
# Out:
#                             OnlinePlacementAssessment  \
# 0                              [open-ended, response]
# 1                                               [nan]
# 2                                               [nan]
# 3                                               [nan]
# 4                                               [nan]
# 5                                               [nan]
# 6                                               [nan]
# 7                                               [nan]
# 8                                               [nan]
# 9                                               [nan]
# 10                                              [nan]
# 11  [make, sure, set, good, amount, time, aside, e...
# 12                                              [nan]
# 13                                              [nan]
# 14                                              [nan]
#
#                                 AcademicAdvising  \
# 0                         [open-ended, response]
# 1                                          [nan]
# 2                                          [nan]
# 3                                          [nan]
# 4                                          [nan]
# 5                                          [nan]
# 6                                          [nan]
# 7                                          [nan]
# 8                                          [nan]
# 9                                          [nan]
# 10                                         [nan]
# 11  [allow, time, student, plan, schedule, meet]
# 12                                         [nan]
# 13                                         [nan]
# 14                                         [nan]
#
#    CollegeOpportunitiesandAdvisingPrep  \
# 0               [open-ended, response]
# 1                                [nan]
# 2                                [nan]
# 3                                [nan]
# 4                                [nan]
# 5                                [nan]
# 6                                [nan]
# 7                                [nan]
# 8                                [nan]
# 9                                [nan]
# 10                               [nan]
# 11                               [nan]
# 12                               [nan]
# 13                               [nan]
# 14                               [nan]
#
#                     spendMoreTimeDestinationKentState  \
# 0                              [open-ended, response]
# 1                                               [nan]
# 2                                               [nan]
# 3                                      [campus, tour]
# 4                                               [nan]
# 5                                               [nan]
# 6                                               [nan]
# 7                                                  []
# 8                  [college, different, high, school]
# 9                                               [nan]
# 10                                              [nan]
# 11  [make, sure, student, get, walk, class, know, ...
# 12                                        [buy, book]
# 13                          [timeline, bill, process]
# 14                                              [nan]
#
#                      favoritePartDestinationKentState  \
# 0                              [open-ended, response]
# 1                                               [nan]
# 2                                               [nan]
# 3                                             [lunch]
# 4                       [spend, night, dorm, helpful]
# 5                                               [nan]
# 6                                               [nan]
# 7   [would, tour, downtown, kent, walk, around, do...
# 8                    [talk, flash, guide, experience]
# 9   [talk, flashguides, life, like, campus, person...
# 10                                              [nan]
# 11  [favorite, part, hear, teh, flashguide, story,...
# 12                                             [food]
# 13  [downtown, tour, great, way, get, feel, surround]
# 14                                              [nan]
#
#                           expectedAsAKentStateStudent   anyAdditionalComments
# 0                              [open-ended, response]  [open-ended, response]
# 1                    [graduate, diploma, give, money]                   [nan]
# 2                                               [nan]                   [nan]
# 3                                              [best]                   [nan]
# 4   [involve, campus, activity, maintain, solid, a...                   [nan]
# 5                                               [nan]                   [nan]
# 6                                               [nan]                   [nan]
# 7   [carry, e, action, word, decision, way, repres...                   [nan]
# 8                [work, time, without, procrastinate]                   [nan]
# 9       [well, show, community, behave, great, human]                   [nan]
# 10                                              [nan]                   [nan]
# 11  [believe, expect, follow, rule, try, best, eve...                   [nan]
# 12                          [live, goal, expectation]                   [nan]
# 13                                          [succeed]                   [nan]
# 14                                 [pas, class, fail]                   [nan]

# %%
# remove remaining tokens that are not alphabetic
for x in data.columns:
    for i in range(len(data)):
        data.loc[i,x] = [word for word in data.loc[i,x] if word.isalpha()]

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\gautam\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
data
# Out:
#                               OnlinePlacementAssessment  \
# 0                                            [response]
# 1                                                 [nan]
# 2                                                 [nan]
# 3                                                 [nan]
# 4                                                 [nan]
# 5                                                 [nan]
# 6                                                 [nan]
# 7                                                 [nan]
# 8                                                 [nan]
# 9                                                 [nan]
# 10                                                [nan]
# 11    [make, sure, set, good, amount, time, aside, e...
# 12                                                [nan]
# 13                                                [nan]
# 14                                                [nan]
# 15                                                [nan]
# 16                                                [nan]
# 17    [level, difficulty, test, maybe, easy, questio...
# 18                                                [nan]
# 19                                                [nan]
# 20    [multiple, choice, answer, could, right, cause...
# 21                                                [nan]
# 22                                                [nan]
# 23                                                [nan]
# 24             [take, one, placement, test, score, act]
# 25                                               [none]
# 26                                                [nan]
# 27                                                [nan]
# 28                                                   []
# 29                                                [nan]
# ...                                                 ...
# 1265                                              [nan]
# 1266                                              [nan]
# 1267                                              [nan]
# 1268                                              [nan]
# 1269  [feedback, clear, many, time, could, retake, p...
# 1270                                              [nan]
# 1271                                              [nan]
# 1272  [math, foreign, language, assessment, would, o...
# 1273                                              [nan]
# 1274                                              [nan]
# 1275                                              [nan]
# 1276                                              [nan]
# 1277                                              [nan]
# 1278                                              [nan]
# 1279  [receive, different, link, take, spanish, plac...
# 1280                                              [nan]
# 1281                                              [nan]
# 1282  [update, use, modern, system, test, allow, stu...
# 1283                                              [nan]
# 1284                                              [nan]
# 1285                                              [nan]
# 1286  [foreign, language, placement, test, issue, wi...
# 1287                                              [nan]
# 1288                                              [nan]
# 1289                                              [nan]
# 1290                                              [nan]
# 1291                                              [nan]
# 1292                                              [nan]
# 1293                                              [nan]
# 1294                                              [nan]
#
#                                        AcademicAdvising  \
# 0                                            [response]
# 1                                                 [nan]
# 2                                                 [nan]
# 3                                                 [nan]
# 4                                                 [nan]
# 5                                                 [nan]
# 6                                                 [nan]
# 7                                                 [nan]
# 8                                                 [nan]
# 9                                                 [nan]
# 10                                                [nan]
# 11         [allow, time, student, plan, schedule, meet]
# 12                                                [nan]
# 13                                                [nan]
# 14                                                [nan]
# 15                                                [nan]
# 16                                                [nan]
# 17    [incredibly, helpful, take, time, schedule, cl...
# 18                                                [nan]
# 19                   [appointment, meet, bc, socialize]
# 20    [good, backup, plan, gas, leak, happen, leader...
# 21                                                [nan]
# 22                                                [nan]
# 23                                                [nan]
# 24    [advisor, amaze, actually, go, time, talk, muc...
# 25                                                [nan]
# 26    [seem, eager, figure, guide, exploratory, majo...
# 27                                                [nan]
# 28                                                [nan]
# 29                                                [nan]
# ...                                                 ...
# 1265                                              [nan]
# 1266                                              [nan]
# 1267                                              [nan]
# 1268            [besides, wait, hour, good, experience]
# 1269                                              [nan]
# 1270                                              [nan]
# 1271                                              [nan]
# 1272                                              [nan]
# 1273                                              [nan]
# 1274                                              [nan]
# 1275                                              [nan]
# 1276  [get, meet, advisor, instead, meet, graduate, ...
# 1277                                              [nan]
# 1278                                              [nan]
# 1279  [first, day, learn, class, would, need, would,...
# 1280                                              [nan]
# 1281                                              [nan]
# 1282                                              [nan]
# 1283                                              [nan]
# 1284                                              [nan]
# 1285                                              [nan]
# 1286                                              [nan]
# 1287                                              [nan]
# 1288         [advisor, friendly, open, question, might]
# 1289                                     [think, amaze]
# 1290                                              [nan]
# 1291  [advisor, maria, really, nice, helpful, appoin...
# 1292                                              [nan]
# 1293                                              [nan]
# 1294                                              [nan]
#
#                     CollegeOpportunitiesandAdvisingPrep  \
# 0                                            [response]
# 1                                                 [nan]
# 2                                                 [nan]
# 3                                                 [nan]
# 4                                                 [nan]
# 5                                                 [nan]
# 6                                                 [nan]
# 7                                                 [nan]
# 8                                                 [nan]
# 9                                                 [nan]
# 10                                                [nan]
# 11                                                [nan]
# 12                                                [nan]
# 13                                                [nan]
# 14                                                [nan]
# 15                                                [nan]
# 16                                                [nan]
# 17    [beautiful, experience, full, genuinely, wonde...
# 18                                                [nan]
# 19                                                [nan]
# 20                                                [nan]
# 21                                                [nan]
# 22                                                [nan]
# 23                                                [nan]
# 24                                                [nan]
# 25                                                [nan]
# 26                                                [nan]
# 27                                                [nan]
# 28                                                [nan]
# 29                                                [nan]
# ...                                                 ...
# 1265                                              [nan]
# 1266                                              [nan]
# 1267                                              [nan]
# 1268                                              [nan]
# 1269                                              [nan]
# 1270                                              [nan]
# 1271                                              [nan]
# 1272                                              [nan]
# 1273                                              [nan]
# 1274                                              [nan]
# 1275                                              [nan]
# 1276                                              [nan]
# 1277                                              [nan]
# 1278                                              [nan]
# 1279  [time, need, spend, talk, actual, class, inste...
# 1280                                              [nan]
# 1281                                              [nan]
# 1282                                              [nan]
# 1283                                              [nan]
# 1284                                              [nan]
# 1285                                              [nan]
# 1286                                              [nan]
# 1287                                              [nan]
# 1288                                              [nan]
# 1289                                             [good]
# 1290                                              [nan]
# 1291                                              [nan]
# 1292                                              [nan]
# 1293                                              [nan]
# 1294                                              [nan]
#
#                       spendMoreTimeDestinationKentState  \
# 0                                            [response]
# 1                                                 [nan]
# 2                                                 [nan]
# 3                                        [campus, tour]
# 4                                                 [nan]
# 5                                                 [nan]
# 6                                                 [nan]
# 7                                                    []
# 8                    [college, different, high, school]
# 9                                                 [nan]
# 10                                                [nan]
# 11    [make, sure, student, get, walk, class, know, ...
# 12                                          [buy, book]
# 13                            [timeline, bill, process]
# 14                                                [nan]
# 15                                                [nan]
# 16                                                [nan]
# 17            [tour, please, also, snack, would, great]
# 18                                                [nan]
# 19    [student, athlete, live, campus, summer, atten...
# 20                                                [nan]
# 21                                                [nan]
# 22                 [tour, campus, downtown, give, time]
# 23                                                [nan]
# 24                                                   []
# 25                                                [nan]
# 26                                                [nan]
# 27                                                [nan]
# 28                                                   []
# 29                                                [nan]
# ...                                                 ...
# 1265                                              [nan]
# 1266                                              [nan]
# 1267                                              [nan]
# 1268                                              [nan]
# 1269                                              [nan]
# 1270  [definetly, tour, campus, along, line, student...
# 1271                                             [park]
# 1272                                              [nan]
# 1273                                              [nan]
# 1274                                              [nan]
# 1275                      [broad, tour, entire, campus]
# 1276                                              [nan]
# 1277                                              [nan]
# 1278                                              [nan]
# 1279  [dks, time, schedule, class, meet, new, people...
# 1280                                              [nan]
# 1281                                      [ccp, credit]
# 1282                                              [nan]
# 1283                                              [nan]
# 1284                                              [nan]
# 1285                                              [nan]
# 1286                                              [nan]
# 1287                                              [nan]
# 1288                                              [nan]
# 1289                              [depth, campus, tour]
# 1290                                              [nan]
# 1291                                              [nan]
# 1292                                              [nan]
# 1293                                              [nan]
# 1294                              [time, learn, campus]
#
#                        favoritePartDestinationKentState  \
# 0                                            [response]
# 1                                                 [nan]
# 2                                                 [nan]
# 3                                               [lunch]
# 4                         [spend, night, dorm, helpful]
# 5                                                 [nan]
# 6                                                 [nan]
# 7     [would, tour, downtown, kent, walk, around, do...
# 8                      [talk, flash, guide, experience]
# 9     [talk, flashguides, life, like, campus, person...
# 10                                                [nan]
# 11    [favorite, part, hear, teh, flashguide, story,...
# 12                                               [food]
# 13    [downtown, tour, great, way, get, feel, surround]
# 14                                                [nan]
# 15                                                [nan]
# 16                                                [nan]
# 17    [really, enjoy, downtime, guy, include, really...
# 18    [go, town, able, walk, around, make, new, frie...
# 19                                                [nan]
# 20                                               [fair]
# 21                                                [nan]
# 22                            [first, lecture, section]
# 23                          [like, night, time, social]
# 24            [tour, downtown, kent, make, new, friend]
# 25                                 [go, downtown, kent]
# 26                                                [nan]
# 27                                     [meet, roommate]
# 28    [go, specific, area, major, speaker, tell, u, ...
# 29                                                [nan]
# ...                                                 ...
# 1265                                              [nan]
# 1266                                              [nan]
# 1267                                              [nan]
# 1268                                              [nan]
# 1269                                              [nan]
# 1270  [absolutely, love, flashguides, confident, inc...
# 1271                  [able, spend, sometime, roommate]
# 1272                                              [nan]
# 1273                                   [even, activity]
# 1274                                             [food]
# 1275     [meet, roomie, experience, make, friend, fall]
# 1276                                              [nan]
# 1277                                              [nan]
# 1278                                              [nan]
# 1279  [favorite, part, end, day, flash, guide, separ...
# 1280                                              [nan]
# 1281  [walk, around, downtown, meet, new, people, en...
# 1282                                              [nan]
# 1283  [like, spend, time, student, college, nice, si...
# 1284                                              [nan]
# 1285                                              [nan]
# 1286                                              [nan]
# 1287                                              [nan]
# 1288                                              [nan]
# 1289  [academic, advise, favorite, part, enjoy, sche...
# 1290                                              [nan]
# 1291  [favorite, part, program, structure, organize,...
# 1292                                              [nan]
# 1293                                              [nan]
# 1294             [free, time, presentation, long, tire]
#
#                             expectedAsAKentStateStudent  \
# 0                                            [response]
# 1                      [graduate, diploma, give, money]
# 2                                                 [nan]
# 3                                                [best]
# 4     [involve, campus, activity, maintain, solid, a...
# 5                                                 [nan]
# 6                                                 [nan]
# 7     [carry, e, action, word, decision, way, repres...
# 8                  [work, time, without, procrastinate]
# 9         [well, show, community, behave, great, human]
# 10                                                [nan]
# 11    [believe, expect, follow, rule, try, best, eve...
# 12                            [live, goal, expectation]
# 13                                            [succeed]
# 14                                   [pas, class, fail]
# 15         [self, sufficient, independent, responsible]
# 16                                                [nan]
# 17                        [success, genuine, happiness]
# 18                              [get, involve, succeed]
# 19                                               [well]
# 20                                               [nice]
# 21                                                [nan]
# 22    [grow, personally, academically, throughout, t...
# 23              [best, get, help, many, resource, need]
# 24    [get, involve, much, possible, make, friend, s...
# 25    [strive, excellence, classroom, support, commu...
# 26                             [hard, work, commitment]
# 27                                  [get, need, credit]
# 28                                            [involve]
# 29    [hold, best, academic, hand, move, forward, fu...
# ...                                                 ...
# 1265                                              [nan]
# 1266    [successful, take, study, seriously, also, fun]
# 1267                                              [nan]
# 1268                                              [nan]
# 1269                    [quality, work, complete, time]
# 1270    [educational, experience, enjoyable, one, well]
# 1271  [maintain, achieve, high, goal, academic, athl...
# 1272                                              [nan]
# 1273                                          [succeed]
# 1274                          [make, year, kent, state]
# 1275  [get, involve, study, hard, enjoy, college, ex...
# 1276                         [ethical, work, hard, etc]
# 1277                                              [nan]
# 1278                  [get, good, grade, study, abroad]
# 1279       [get, involve, make, friend, keep, academic]
# 1280                          [involvement, university]
# 1281  [take, education, seriously, also, fun, make, ...
# 1282          [get, involve, go, degree, find, purpose]
# 1283  [believe, academically, successful, student, a...
# 1284                                             [good]
# 1285                                            [adult]
# 1286                                              [nan]
# 1287                                 [set, goal, stick]
# 1288                                              [nan]
# 1289              [academic, excellence, self, purpose]
# 1290                                              [nan]
# 1291  [expect, best, become, successful, discover, p...
# 1292                                     [behave, well]
# 1293                                       [excellence]
# 1294                                         [graduate]
#
#                                   anyAdditionalComments
# 0                                            [response]
# 1                                                 [nan]
# 2                                                 [nan]
# 3                                                 [nan]
# 4                                                 [nan]
# 5                                                 [nan]
# 6                                                 [nan]
# 7                                                 [nan]
# 8                                                 [nan]
# 9                                                 [nan]
# 10                                                [nan]
# 11                                                [nan]
# 12                                                [nan]
# 13                                                [nan]
# 14                                                [nan]
# 15                                                [nan]
# 16                                                [nan]
# 17          [appreciate, every, one, supporter, future]
# 18                                                [nan]
# 19                                                [nan]
# 20                                                [nan]
# 21                                                [nan]
# 22                                                [nan]
# 23                                                [nan]
# 24                                                [nan]
# 25                                                [nan]
# 26                                                [nan]
# 27                                                [nan]
# 28                           [love, opportunity, would]
# 29                                                [nan]
# ...                                                 ...
# 1265                                              [nan]
# 1266                                              [nan]
# 1267                                              [nan]
# 1268                                              [nan]
# 1269                                              [nan]
# 1270                                        [go, flash]
# 1271                                              [nan]
# 1272                                              [nan]
# 1273  [use, different, teacher, teach, u, first, cla...
# 1274                                              [nan]
# 1275                                              [nan]
# 1276                                              [nan]
# 1277                                              [nan]
# 1278                                              [nan]
# 1279  [suggest, day, mix, schedule, speech, activity...
# 1280                                              [nan]
# 1281                                              [nan]
# 1282                                              [nan]
# 1283                                              [nan]
# 1284                                              [nan]
# 1285                                              [nan]
# 1286                                              [nan]
# 1287                                              [nan]
# 1288                                              [nan]
# 1289  [would, like, flash, guide, involve, session, ...
# 1290                                              [nan]
# 1291                                              [nan]
# 1292                                              [nan]
# 1293                                              [nan]
# 1294                                              [nan]
#
# [1295 rows x 7 columns]

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\gautam\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
#Checking the words are english word or not, if not then remove it.
from nltk.corpus import words

for x in data.columns:
    for i in range(len(data)):
        data.loc[i,x] = [word for word in data.loc[i,x] if word in words.words()]

# %%
# saving cleaned Data into the CSV file
data.to_csv('Desktop\\cleaned_Destination_Kent_State_Student_Evaluation_2017.csv', index=False)
